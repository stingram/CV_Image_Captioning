# %% [markdown]
# # Computer Vision Nanodegree
#
# ## Project: Image Captioning - REQUIRES GPU ENABLED ENVIRONMENT
#
# ---
#
# In this notebook, we train our CNN-RNN model.
#
# Feel free to use the links below to navigate the notebook:
# - [Step 1](#step1): Training Setup
# - [Step 2](#step2): Train your Model
# - [Step 3](#step3): (Optional) Validate your Model

# %% [markdown]
# <a id='step1'></a>
# ## Step 1: Training Setup
#
# In this step of the notebook, we will customize the training of your CNN-RNN model by specifying hyperparameters and setting other options that are important to the training procedure.  The values we set now will be used when training your model in **Step 2** below.
#
# Begin by setting the following variables:
# - `batch_size` - the batch size of each training batch.  It is the number of image-caption pairs used to amend the model weights in each training step.
# - `vocab_threshold` - the minimum word count threshold.  Note that a larger threshold will result in a smaller vocabulary, whereas a smaller threshold will include rarer words and result in a larger vocabulary.
# - `vocab_from_file` - a Boolean that decides whether to load the vocabulary from file.
# - `embed_size` - the dimensionality of the image and word embeddings.
# - `hidden_size` - the number of features in the hidden state of the RNN decoder.
# - `num_epochs` - the number of epochs to train the model.  We recommend that you set `num_epochs=3`, but feel free to increase or decrease this number as you wish.  [This paper](https://arxiv.org/pdf/1502.03044.pdf) trained a captioning model on a single state-of-the-art GPU for 3 days, but you'll see that you can get reasonable results in a matter of a few hours!  (_But of course, if we want our model to compete with current research, we will have to train for much longer._)
# - `save_every` - determines how often to save the model weights.
# - `print_every` - determines how often to print the batch loss to the Jupyter notebook while training.  Note that you **will not** observe a monotonic decrease in the loss function while training - this is perfectly fine and completely expected!
# - `log_file` - the name of the text file containing - for every step - how the loss and perplexity evolved during training.

# %%
import torch
import torch.nn as nn
from torchvision import transforms
import sys
sys.path.append('/opt/cocoapi/PythonAPI')
from pycocotools.coco import COCO
from data_loader import get_loader
from model import EncoderCNN, DecoderRNN
import math

# !pip install nltk
import nltk
nltk.download('punkt')


## Select appropriate values for the Python variables below.
batch_size = 64          # batch size
vocab_threshold = 5        # minimum word count threshold
vocab_from_file = True    # if True, load existing vocab file
embed_size = 512           # dimensionality of image and word embeddings
hidden_size = 512          # number of features in hidden state of the RNN decoder
num_epochs = 3             # number of training epochs
save_every = 1             # determines frequency of saving model weights
print_every = 100          # determines window for printing average loss
log_file = 'training_log.txt'       # name of file with saved training loss and perplexity

# Image Transform
transform_train = transforms.Compose([ 
    transforms.Resize(256),                          # smaller edge of image resized to 256
    transforms.RandomCrop(224),                      # get 224x224 crop from random location
    transforms.RandomHorizontalFlip(),               # horizontally flip image with probability=0.5
    transforms.ToTensor(),                           # convert the PIL Image to a tensor
    transforms.Normalize((0.485, 0.456, 0.406),      # normalize image for pre-trained model
                         (0.229, 0.224, 0.225))])

# Build data loader.
data_loader = get_loader(transform=transform_train,
                         mode='train',
                         batch_size=batch_size,
                         vocab_threshold=vocab_threshold,
                         vocab_from_file=vocab_from_file)

# The size of the vocabulary.
vocab_size = len(data_loader.dataset.vocab)

# Initialize the encoder and decoder. 
encoder = EncoderCNN(embed_size)
decoder = DecoderRNN(embed_size, hidden_size, vocab_size)

# Move models to GPU if CUDA is available. 
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
encoder.to(device)
decoder.to(device)

# Define the loss function. 
criterion = nn.CrossEntropyLoss().cuda() if torch.cuda.is_available() else nn.CrossEntropyLoss()

# Specifies the learnable parameters of the model.
params = list(decoder.parameters()) + list(encoder.embed.parameters())

# Defines the optimizer.
optimizer = torch.optim.Adam(params)

# Set the total number of training steps per epoch.
total_step = math.ceil(len(data_loader.dataset.caption_lengths) / data_loader.batch_sampler.batch_size)
# Out:
# Requirement already satisfied: nltk in /opt/conda/lib/python3.6/site-packages (3.2.5)
# Requirement already satisfied: six in /opt/conda/lib/python3.6/site-packages (from nltk) (1.11.0)
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# Vocabulary successfully loaded from vocab.pkl file!
# loading annotations into memory...
# Done (t=1.06s)
# creating index...
#   0%|          | 587/414113 [00:00<02:41, 2566.08it/s]
# index created!
# Obtaining caption lengths...
# 100%|██████████| 414113/414113 [02:00<00:00, 3436.84it/s]
# Downloading: "https://download.pytorch.org/models/resnet50-19c8e357.pth" to /root/.torch/models/resnet50-19c8e357.pth
# 100%|██████████| 102502400/102502400 [00:01<00:00, 88100214.25it/s]

# %% [markdown]
# <a id='step2'></a>
# ## Step 2: Train the Model
#
# Once you have executed the code cell in **Step 1**, the training procedure below should run without issue.
#
# You may find it useful to load saved weights to resume training.  In that case, note the names of the files containing the encoder and decoder weights that you'd like to load (`encoder_file` and `decoder_file`).  Then you can load the weights by using the lines below:
#
# ```python
# # Load pre-trained weights before resuming training.
# encoder.load_state_dict(torch.load(os.path.join('./models', encoder_file)))
# decoder.load_state_dict(torch.load(os.path.join('./models', decoder_file)))
# ```
#
# ### A Note on Tuning Hyperparameters
#
# To figure out how well your model is doing, you can look at how the training loss and perplexity evolve during training.

# %%
import torch.utils.data as data
import numpy as np
import os
import requests
import time

# Open the training log file.
f = open(log_file, 'w')

old_time = time.time()
response = requests.request("GET", 
                            "http://metadata.google.internal/computeMetadata/v1/instance/attributes/keep_alive_token", 
                            headers={"Metadata-Flavor":"Google"})

for epoch in range(1, num_epochs+1):
    
    for i_step in range(1, total_step+1):
        
        if time.time() - old_time > 60:
            old_time = time.time()
            requests.request("POST", 
                             "https://nebula.udacity.com/api/v1/remote/keep-alive", 
                             headers={'Authorization': "STAR " + response.text})
        
        # Randomly sample a caption length, and sample indices with that length.
        indices = data_loader.dataset.get_train_indices()
        # Create and assign a batch sampler to retrieve a batch with the sampled indices.
        new_sampler = data.sampler.SubsetRandomSampler(indices=indices)
        data_loader.batch_sampler.sampler = new_sampler
        
        # Obtain the batch.
        images, captions = next(iter(data_loader))

        # Move batch of images and captions to GPU if CUDA is available.
        images = images.to(device)
        captions = captions.to(device)
        
        # Zero the gradients.
        decoder.zero_grad()
        encoder.zero_grad()
        
        # Pass the inputs through the CNN-RNN model.
        features = encoder(images)
        outputs = decoder(features, captions)
        
        # Calculate the batch loss.
        loss = criterion(outputs.view(-1, vocab_size), captions.view(-1))
        
        # Backward pass.
        loss.backward()
        
        # Update the parameters in the optimizer.
        optimizer.step()
            
        # Get training statistics.
        stats = 'Epoch [%d/%d], Step [%d/%d], Loss: %.4f, Perplexity: %5.4f' % (epoch, num_epochs, i_step, total_step, loss.item(), np.exp(loss.item()))
        
        # Print training statistics (on same line).
        print('\r' + stats, end="")
        sys.stdout.flush()
        
        # Print training statistics to file.
        f.write(stats + '\n')
        f.flush()
        
        # Print training statistics (on different line).
        if i_step % print_every == 0:
            print('\r' + stats)
            
    # Save the weights.
    if epoch % save_every == 0:
        torch.save(decoder.state_dict(), os.path.join('./models', 'decoder-%d.pkl' % epoch))
        torch.save(encoder.state_dict(), os.path.join('./models', 'encoder-%d.pkl' % epoch))

# Close the training log file.
f.close()
# Out:
# Epoch [1/3], Step [100/6471], Loss: 4.2852, Perplexity: 72.6136
# Epoch [1/3], Step [200/6471], Loss: 3.7393, Perplexity: 42.06663
# Epoch [1/3], Step [300/6471], Loss: 3.6163, Perplexity: 37.2000
# Epoch [1/3], Step [400/6471], Loss: 3.7043, Perplexity: 40.6220
# Epoch [1/3], Step [500/6471], Loss: 3.4114, Perplexity: 30.3089
# Epoch [1/3], Step [600/6471], Loss: 3.1832, Perplexity: 24.1235
# Epoch [1/3], Step [700/6471], Loss: 3.2339, Perplexity: 25.3791
# Epoch [1/3], Step [800/6471], Loss: 3.1578, Perplexity: 23.5187
# Epoch [1/3], Step [900/6471], Loss: 3.2890, Perplexity: 26.8157
# Epoch [1/3], Step [1000/6471], Loss: 3.0850, Perplexity: 21.8683
# Epoch [1/3], Step [1100/6471], Loss: 2.7278, Perplexity: 15.2994
# Epoch [1/3], Step [1200/6471], Loss: 2.9145, Perplexity: 18.4393
# Epoch [1/3], Step [1300/6471], Loss: 2.8461, Perplexity: 17.2211
# Epoch [1/3], Step [1400/6471], Loss: 3.2270, Perplexity: 25.2037
# Epoch [1/3], Step [1500/6471], Loss: 2.6727, Perplexity: 14.4786
# Epoch [1/3], Step [1600/6471], Loss: 2.9829, Perplexity: 19.7458
# Epoch [1/3], Step [1700/6471], Loss: 2.6042, Perplexity: 13.5202
# Epoch [1/3], Step [1800/6471], Loss: 2.7463, Perplexity: 15.5853
# Epoch [1/3], Step [1900/6471], Loss: 2.5537, Perplexity: 12.8552
# Epoch [1/3], Step [2000/6471], Loss: 2.5633, Perplexity: 12.9791
# Epoch [1/3], Step [2100/6471], Loss: 2.7400, Perplexity: 15.4873
# Epoch [1/3], Step [2200/6471], Loss: 2.6813, Perplexity: 14.6033
# Epoch [1/3], Step [2300/6471], Loss: 2.6695, Perplexity: 14.4328
# Epoch [1/3], Step [2400/6471], Loss: 2.5772, Perplexity: 13.16013
# Epoch [1/3], Step [2500/6471], Loss: 2.5336, Perplexity: 12.5990
# Epoch [1/3], Step [2600/6471], Loss: 2.6916, Perplexity: 14.7554
# Epoch [1/3], Step [2700/6471], Loss: 2.7877, Perplexity: 16.2432
# Epoch [1/3], Step [2800/6471], Loss: 2.3299, Perplexity: 10.2771
# Epoch [1/3], Step [2900/6471], Loss: 2.1180, Perplexity: 8.314439
# Epoch [1/3], Step [3000/6471], Loss: 2.5104, Perplexity: 12.3102
# Epoch [1/3], Step [3100/6471], Loss: 2.4397, Perplexity: 11.4696
# Epoch [1/3], Step [3200/6471], Loss: 2.3006, Perplexity: 9.98022
# Epoch [1/3], Step [3300/6471], Loss: 2.2439, Perplexity: 9.43022
# Epoch [1/3], Step [3400/6471], Loss: 2.4113, Perplexity: 11.14827
# Epoch [1/3], Step [3500/6471], Loss: 2.6295, Perplexity: 13.8674
# Epoch [1/3], Step [3600/6471], Loss: 2.2496, Perplexity: 9.48387
# Epoch [1/3], Step [3700/6471], Loss: 2.7200, Perplexity: 15.1806
# Epoch [1/3], Step [3800/6471], Loss: 2.4854, Perplexity: 12.0064
# Epoch [1/3], Step [3900/6471], Loss: 2.7286, Perplexity: 15.3119
# Epoch [1/3], Step [4000/6471], Loss: 2.3725, Perplexity: 10.7241
# Epoch [1/3], Step [4100/6471], Loss: 2.4156, Perplexity: 11.1966
# Epoch [1/3], Step [4200/6471], Loss: 3.3041, Perplexity: 27.2250
# Epoch [1/3], Step [4300/6471], Loss: 2.4212, Perplexity: 11.2599
# Epoch [1/3], Step [4400/6471], Loss: 2.6186, Perplexity: 13.7168
# Epoch [1/3], Step [4500/6471], Loss: 2.4439, Perplexity: 11.5178
# Epoch [1/3], Step [4600/6471], Loss: 2.4167, Perplexity: 11.2090
# Epoch [1/3], Step [4700/6471], Loss: 2.3864, Perplexity: 10.8743
# Epoch [1/3], Step [4800/6471], Loss: 2.9199, Perplexity: 18.5397
# Epoch [1/3], Step [4900/6471], Loss: 2.2675, Perplexity: 9.65553
# Epoch [1/3], Step [5000/6471], Loss: 2.3517, Perplexity: 10.5031
# Epoch [1/3], Step [5100/6471], Loss: 2.2543, Perplexity: 9.52820
# Epoch [1/3], Step [5200/6471], Loss: 2.6194, Perplexity: 13.7269
# Epoch [1/3], Step [5300/6471], Loss: 2.4053, Perplexity: 11.0815
# Epoch [1/3], Step [5400/6471], Loss: 2.7292, Perplexity: 15.3205
# Epoch [1/3], Step [5500/6471], Loss: 2.2907, Perplexity: 9.88161
# Epoch [1/3], Step [5600/6471], Loss: 2.3285, Perplexity: 10.2627
# Epoch [1/3], Step [5700/6471], Loss: 2.6118, Perplexity: 13.6230
# Epoch [1/3], Step [5800/6471], Loss: 2.4334, Perplexity: 11.3976
# Epoch [1/3], Step [5900/6471], Loss: 2.1595, Perplexity: 8.66706
# Epoch [1/3], Step [6000/6471], Loss: 2.8519, Perplexity: 17.3213
# Epoch [1/3], Step [6100/6471], Loss: 2.2028, Perplexity: 9.05044
# Epoch [1/3], Step [6200/6471], Loss: 2.2276, Perplexity: 9.27806
# Epoch [1/3], Step [6300/6471], Loss: 2.2310, Perplexity: 9.30928
# Epoch [1/3], Step [6400/6471], Loss: 2.6119, Perplexity: 13.6251
# Epoch [2/3], Step [100/6471], Loss: 2.2874, Perplexity: 9.849735
# Epoch [2/3], Step [200/6471], Loss: 2.1327, Perplexity: 8.43781
# Epoch [2/3], Step [300/6471], Loss: 2.0888, Perplexity: 8.07534
# Epoch [2/3], Step [400/6471], Loss: 2.2203, Perplexity: 9.20975
# Epoch [2/3], Step [500/6471], Loss: 2.4428, Perplexity: 11.5053
# Epoch [2/3], Step [600/6471], Loss: 1.9562, Perplexity: 7.07262
# Epoch [2/3], Step [700/6471], Loss: 2.4017, Perplexity: 11.0414
# Epoch [2/3], Step [800/6471], Loss: 2.3765, Perplexity: 10.7669
# Epoch [2/3], Step [900/6471], Loss: 2.4588, Perplexity: 11.6909
# Epoch [2/3], Step [1000/6471], Loss: 2.2801, Perplexity: 9.7781
# Epoch [2/3], Step [1100/6471], Loss: 2.2082, Perplexity: 9.09966
# Epoch [2/3], Step [1200/6471], Loss: 2.0784, Perplexity: 7.99199
# Epoch [2/3], Step [1300/6471], Loss: 2.2103, Perplexity: 9.11842
# Epoch [2/3], Step [1400/6471], Loss: 2.4808, Perplexity: 11.9509
# Epoch [2/3], Step [1500/6471], Loss: 2.3225, Perplexity: 10.2010
# Epoch [2/3], Step [1600/6471], Loss: 2.3170, Perplexity: 10.1451
# Epoch [2/3], Step [1700/6471], Loss: 2.5929, Perplexity: 13.3690
# Epoch [2/3], Step [1800/6471], Loss: 2.0730, Perplexity: 7.94898
# Epoch [2/3], Step [1900/6471], Loss: 2.0954, Perplexity: 8.12831
# Epoch [2/3], Step [2000/6471], Loss: 2.1613, Perplexity: 8.68219
# Epoch [2/3], Step [2100/6471], Loss: 1.9208, Perplexity: 6.82629
# Epoch [2/3], Step [2200/6471], Loss: 2.0421, Perplexity: 7.70694
# Epoch [2/3], Step [2300/6471], Loss: 2.3100, Perplexity: 10.07481
# Epoch [2/3], Step [2400/6471], Loss: 2.2685, Perplexity: 9.66499
# Epoch [2/3], Step [2500/6471], Loss: 2.4244, Perplexity: 11.2950
# Epoch [2/3], Step [2600/6471], Loss: 2.1394, Perplexity: 8.49400
# Epoch [2/3], Step [2700/6471], Loss: 2.1106, Perplexity: 8.25307
# Epoch [2/3], Step [2800/6471], Loss: 2.0557, Perplexity: 7.81211
# Epoch [2/3], Step [2900/6471], Loss: 2.3439, Perplexity: 10.4214
# Epoch [2/3], Step [3000/6471], Loss: 2.1117, Perplexity: 8.26271
# Epoch [2/3], Step [3100/6471], Loss: 2.0040, Perplexity: 7.41862
# Epoch [2/3], Step [3200/6471], Loss: 2.1062, Perplexity: 8.21695
# Epoch [2/3], Step [3300/6471], Loss: 2.3543, Perplexity: 10.5305
# Epoch [2/3], Step [3400/6471], Loss: 2.2713, Perplexity: 9.69192
# Epoch [2/3], Step [3500/6471], Loss: 2.0881, Perplexity: 8.06988
# Epoch [2/3], Step [3600/6471], Loss: 2.0866, Perplexity: 8.05787
# Epoch [2/3], Step [3700/6471], Loss: 2.2345, Perplexity: 9.34163
# Epoch [2/3], Step [3800/6471], Loss: 2.1923, Perplexity: 8.95611
# Epoch [2/3], Step [3900/6471], Loss: 2.3220, Perplexity: 10.1956
# Epoch [2/3], Step [4000/6471], Loss: 2.2584, Perplexity: 9.56812
# Epoch [2/3], Step [4100/6471], Loss: 1.9564, Perplexity: 7.07385
# Epoch [2/3], Step [4200/6471], Loss: 2.3056, Perplexity: 10.0304
# Epoch [2/3], Step [4300/6471], Loss: 2.2457, Perplexity: 9.44701
# Epoch [2/3], Step [4400/6471], Loss: 2.7257, Perplexity: 15.2670
# Epoch [2/3], Step [4500/6471], Loss: 2.0491, Perplexity: 7.76075
# Epoch [2/3], Step [4600/6471], Loss: 2.2088, Perplexity: 9.10488
# Epoch [2/3], Step [4700/6471], Loss: 2.1536, Perplexity: 8.61611
# Epoch [2/3], Step [4800/6471], Loss: 2.0965, Perplexity: 8.13732
# Epoch [2/3], Step [4900/6471], Loss: 2.1398, Perplexity: 8.49756
# Epoch [2/3], Step [5000/6471], Loss: 2.1339, Perplexity: 8.44754
# Epoch [2/3], Step [5100/6471], Loss: 2.1190, Perplexity: 8.32321
# Epoch [2/3], Step [5200/6471], Loss: 2.0311, Perplexity: 7.62265
# Epoch [2/3], Step [5300/6471], Loss: 2.1029, Perplexity: 8.19025
# Epoch [2/3], Step [5400/6471], Loss: 2.0043, Perplexity: 7.42118
# Epoch [2/3], Step [5500/6471], Loss: 2.8636, Perplexity: 17.5237
# Epoch [2/3], Step [5600/6471], Loss: 2.3704, Perplexity: 10.7019
# Epoch [2/3], Step [5700/6471], Loss: 2.1359, Perplexity: 8.46507
# Epoch [2/3], Step [5800/6471], Loss: 2.1509, Perplexity: 8.59302
# Epoch [2/3], Step [5900/6471], Loss: 2.1049, Perplexity: 8.20602
# Epoch [2/3], Step [6000/6471], Loss: 1.9084, Perplexity: 6.74232
# Epoch [2/3], Step [6100/6471], Loss: 2.1445, Perplexity: 8.53817
# Epoch [2/3], Step [6200/6471], Loss: 2.2409, Perplexity: 9.40177
# Epoch [2/3], Step [6300/6471], Loss: 2.2599, Perplexity: 9.58203
# Epoch [2/3], Step [6400/6471], Loss: 2.1036, Perplexity: 8.19573
# Epoch [3/3], Step [100/6471], Loss: 2.7525, Perplexity: 15.68226
# Epoch [3/3], Step [200/6471], Loss: 2.1776, Perplexity: 8.82528
# Epoch [3/3], Step [300/6471], Loss: 2.1315, Perplexity: 8.42744
# Epoch [3/3], Step [400/6471], Loss: 2.1361, Perplexity: 8.46672
# Epoch [3/3], Step [500/6471], Loss: 2.1702, Perplexity: 8.76006
# Epoch [3/3], Step [600/6471], Loss: 1.9643, Perplexity: 7.12998
# Epoch [3/3], Step [700/6471], Loss: 2.2786, Perplexity: 9.76280
# Epoch [3/3], Step [800/6471], Loss: 2.6297, Perplexity: 13.8701
# Epoch [3/3], Step [900/6471], Loss: 2.0389, Perplexity: 7.68229
# Epoch [3/3], Step [1000/6471], Loss: 2.0950, Perplexity: 8.1252
# Epoch [3/3], Step [1100/6471], Loss: 2.0304, Perplexity: 7.61694
# Epoch [3/3], Step [1200/6471], Loss: 2.0317, Perplexity: 7.62726
# Epoch [3/3], Step [1300/6471], Loss: 2.6379, Perplexity: 13.9841
# Epoch [3/3], Step [1400/6471], Loss: 2.0852, Perplexity: 8.04622
# Epoch [3/3], Step [1500/6471], Loss: 2.7692, Perplexity: 15.9453
# Epoch [3/3], Step [1600/6471], Loss: 2.0444, Perplexity: 7.72423
# Epoch [3/3], Step [1700/6471], Loss: 2.2343, Perplexity: 9.34017
# Epoch [3/3], Step [1800/6471], Loss: 2.0479, Perplexity: 7.75193
# Epoch [3/3], Step [1900/6471], Loss: 1.9202, Perplexity: 6.82215
# Epoch [3/3], Step [2000/6471], Loss: 2.1326, Perplexity: 8.43660
# Epoch [3/3], Step [2100/6471], Loss: 2.0682, Perplexity: 7.91055
# Epoch [3/3], Step [2200/6471], Loss: 1.9998, Perplexity: 7.38757
# Epoch [3/3], Step [2300/6471], Loss: 1.9065, Perplexity: 6.72975
# Epoch [3/3], Step [2400/6471], Loss: 2.0438, Perplexity: 7.71993
# Epoch [3/3], Step [2500/6471], Loss: 2.0999, Perplexity: 8.16512
# Epoch [3/3], Step [2600/6471], Loss: 2.4783, Perplexity: 11.9214
# Epoch [3/3], Step [2700/6471], Loss: 2.3477, Perplexity: 10.4612
# Epoch [3/3], Step [2800/6471], Loss: 2.1161, Perplexity: 8.29905
# Epoch [3/3], Step [2900/6471], Loss: 2.1092, Perplexity: 8.24173
# Epoch [3/3], Step [3000/6471], Loss: 1.9828, Perplexity: 7.26345
# Epoch [3/3], Step [3100/6471], Loss: 2.3123, Perplexity: 10.0974
# Epoch [3/3], Step [3200/6471], Loss: 2.2084, Perplexity: 9.10124
# Epoch [3/3], Step [3300/6471], Loss: 1.9532, Perplexity: 7.05141
# Epoch [3/3], Step [3400/6471], Loss: 2.0529, Perplexity: 7.79065
# Epoch [3/3], Step [3500/6471], Loss: 2.1250, Perplexity: 8.37321
# Epoch [3/3], Step [3600/6471], Loss: 1.9939, Perplexity: 7.34413
# Epoch [3/3], Step [3700/6471], Loss: 2.1162, Perplexity: 8.29955
# Epoch [3/3], Step [3800/6471], Loss: 1.9132, Perplexity: 6.77494
# Epoch [3/3], Step [3900/6471], Loss: 1.9035, Perplexity: 6.70907
# Epoch [3/3], Step [4000/6471], Loss: 2.3993, Perplexity: 11.0156
# Epoch [3/3], Step [4100/6471], Loss: 1.9990, Perplexity: 7.38171
# Epoch [3/3], Step [4200/6471], Loss: 1.9417, Perplexity: 6.970910
# Epoch [3/3], Step [4300/6471], Loss: 1.9611, Perplexity: 7.10732
# Epoch [3/3], Step [4400/6471], Loss: 2.1491, Perplexity: 8.57676
# Epoch [3/3], Step [4500/6471], Loss: 2.2180, Perplexity: 9.18897
# Epoch [3/3], Step [4600/6471], Loss: 2.0240, Perplexity: 7.56840
# Epoch [3/3], Step [4700/6471], Loss: 2.2402, Perplexity: 9.39561
# Epoch [3/3], Step [4800/6471], Loss: 1.8769, Perplexity: 6.53357
# Epoch [3/3], Step [4900/6471], Loss: 1.9058, Perplexity: 6.72504
# Epoch [3/3], Step [5000/6471], Loss: 1.9703, Perplexity: 7.17296
# Epoch [3/3], Step [5100/6471], Loss: 1.9247, Perplexity: 6.85298
# Epoch [3/3], Step [5200/6471], Loss: 1.8659, Perplexity: 6.46183
# Epoch [3/3], Step [5300/6471], Loss: 2.0711, Perplexity: 7.93387
# Epoch [3/3], Step [5400/6471], Loss: 1.9476, Perplexity: 7.01162
# Epoch [3/3], Step [5500/6471], Loss: 2.0871, Perplexity: 8.06188
# Epoch [3/3], Step [5600/6471], Loss: 1.9362, Perplexity: 6.93264
# Epoch [3/3], Step [5700/6471], Loss: 2.0532, Perplexity: 7.79292
# Epoch [3/3], Step [5800/6471], Loss: 2.0158, Perplexity: 7.50640
# Epoch [3/3], Step [5900/6471], Loss: 2.0171, Perplexity: 7.51639
# Epoch [3/3], Step [6000/6471], Loss: 1.9064, Perplexity: 6.72855
# Epoch [3/3], Step [6100/6471], Loss: 1.9867, Perplexity: 7.29122
# Epoch [3/3], Step [6200/6471], Loss: 2.2956, Perplexity: 9.93002
# Epoch [3/3], Step [6300/6471], Loss: 1.9640, Perplexity: 7.12817
# Epoch [3/3], Step [6400/6471], Loss: 2.4193, Perplexity: 11.2376
# Epoch [3/3], Step [6471/6471], Loss: 2.0457, Perplexity: 7.73451

# %% [markdown]
# <a id='step3'></a>
# ## Step 3: (Optional) Validate your Model
#
# To assess potential overfitting, one approach is to assess performance on a validation set.
#
# If you decide to validate your model, please do not edit the data loader in **data_loader.py**.  Instead, create a new file named **data_loader_val.py** containing the code for obtaining the data loader for the validation data.  You can access:
# - the validation images at filepath `'/opt/cocoapi/images/train2014/'`, and
# - the validation image caption annotation file at filepath `'/opt/cocoapi/annotations/captions_val2014.json'`.
#
# The suggested approach to validating your model involves creating a json file such as [this one](https://github.com/cocodataset/cocoapi/blob/master/results/captions_val2014_fakecap_results.json) containing your model's predicted captions for the validation images.  Then, you can write your own script or use one that you [find online](https://github.com/tylin/coco-caption) to calculate the BLEU score of your model.  You can read more about the BLEU score, along with other evaluation metrics (such as TEOR and Cider) in section 4.1 of [this paper](https://arxiv.org/pdf/1411.4555.pdf).  For more information about how to use the annotation file, check out the [website](http://cocodataset.org/#download) for the COCO dataset.

# %%
# (Optional): Validate your model.
